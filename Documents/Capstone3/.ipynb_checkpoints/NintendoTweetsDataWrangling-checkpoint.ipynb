# %% [markdown]
# # Nintendo Tweets Data Wrangling

# %% [markdown]
# Our data set is a collection of about 100000 tweets during Nintendo's Conference at E3 2018. Of the major titles that they're announcing, we'll specifically be looking at Super Smash Bros Ultimate, Fire Emblem: Three Houses, and Super Mario Party. Therefore we will be cleaning and identifying the tweets that are related to these titles only.

# %%
import pandas as pd
import os
import matplotlib.pyplot as plt
import numpy as np
from textblob import TextBlob
from langdetect import detect, DetectorFactory
import re
from emoji import UNICODE_EMOJI
from nltk.corpus import wordnet as wn
import nltk

# %%
path = "/Users/jasonzhou/Documents/GitHub/NintendoTweets/Documents/Capstone3"
os.chdir(path)

NintendoTweets = pd.read_json("NintendoTweets.json", lines=True,
                        orient='columns')
NintendoTweets = NintendoTweets[['text', 'entities']]

pd.options.display.max_colwidth = 200

# %%
NintendoTweets.shape
# Out:
# (104695, 2)

# %% [markdown]
# To-Do List:
#
# - Clean up text bodies of tweets to ignore hashtags, links, and other irrelevant information. Drop tweets with no real text body
# - Drop tweets in foreign languages, our modeling can only handle English text
# - Standardize hashtags of interest
# - Merge column of hashtag values to corresponding tweets
# - Drop tweets that are unrelated to our topics/hashtags of interest
# - Sort tweets by hashtags of interest, and export into separate csv files by game

# %% [markdown]
# We're only interested in a select few attributes, the text body of the tweet and any hashtags involved.
#
# First, we need to clean up the formatting of the text bodies of our tweets to get the relevant words. I shall define some useful helper functions to help filter out any unwanted strings.

# %%
# Removes punctuation 

def filterPunc(string):
    return re.sub('[,\.!?@:]', '', string)

# %%
# Removes URL's

def filterURL(string): 
    regex = r"(?i)\b((?:https?://|www\d{0,3}[.]|[a-z0-9.\-]+[.][a-z]{2,4}/)(?:[^\s()<>]+|\(([^\s()<>]+|(\([^\s()<>]+\)))*\))+(?:\(([^\s()<>]+|(\([^\s()<>]+\)))*\)|[^\s`!()\[\]{};:'\".,<>?«»“”‘’]))"
    urls = re.findall(regex,string)
    if len(urls) != 0:
        string = string.replace(str(urls[0][0]), '')
    return string

# %%
# Removes hashtags

def filterHashtag(string):
    regex = r"#(\w+)"
    hashtags = re.findall(regex, string)
    for hashtag in hashtags:
        string = string.replace('#' + hashtag, '')
    return string

# %%
# Removes emojis

def filterEmoji(string):
    emoji_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags (iOS)
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoji_pattern.sub(r'', string)

# %%
# Removes textual noise in beginning

def filterHead(string):
    return string.split(maxsplit=1)[1]

# %%
# Removes textual noise on the end

def filterTail(string):
    return string.split("\nName:")[0]

# %%
# Filtering out HTML text

def filterNewLine(string):
    string = string.replace("\\n", '')
    string = string.replace("\\r", '')
    return string

# %%
# Takes singular form of every word where applicable

def singularize(string):
    sentence = TextBlob(string)
    sentence = sentence.words.singularize()
    result = ""
    for word in sentence:
        result = result + word + " "
    return result

# %%
# Filters most words that aren't English and ignores stopwords

from nltk.corpus import stopwords
stop_words = set(stopwords.words('english'))

def filterWords(string):
    words = string.split()
    actualwords = []
    for word in words:
        if len(wn.synsets(word)) != 0 and len(word) > 1 and word not in stop_words:
            actualwords.append(word)
    result = ""
    for actualword in actualwords:
        result = result + actualword + " "
    return result

# %%
# Standardizes tense, so for example "ran" and "run" will be considered the same word

from textblob import Word

def lemmatize(string):
    words = string.split()
    actualwords = []
    result = ""
    for word in words:
        actualwords.append(Word(word).lemmatize())
    for actualword in actualwords:
        result = result + actualword + " "
    return result

# %%
# Filters numbers out of the string

def filterNum(string):
    words = string.split()
    actualwords = []
    result = ""
    
    for word in words:
        if not word.isdigit():
            actualwords.append(word)
    
    for actualword in actualwords:
        result = result + actualword + " "
    
    return result

# %% [markdown]
# Here we'll be using each of our helper functions to clean out everything in the body of the tweet that isn't an English word.

# %%
# Filtering tweet text bodies

cleanedTweets = []

for i in range(len(NintendoTweets)):
    textbody = str(NintendoTweets.iloc[[i]]['text'])
    textbody = filterHead(textbody)
    textbody = filterTail(textbody)
    textbody = filterHashtag(textbody)
    textbody = filterEmoji(textbody)
    textbody = filterNewLine(textbody)
    textbody = filterURL(textbody)
    textbody = filterURL(textbody)
    textbody = filterPunc(textbody)
    textbody = singularize(textbody)
    textbody = filterWords(textbody)
    textbody = lemmatize(textbody)
    textbody = filterNum(textbody)
    cleanedTweets.append(textbody.lower())

# %% [markdown]
# The "entities" feature is a bit too messy and cluttered for our liking, we're only interested in the hashtags so we'll be extracting those here.

# %%
# Create list of all hashtags

hashtaglist = []
for i in range(len(NintendoTweets)):
    hashtags = []
    hts = NintendoTweets.iloc[[i]]['entities'].iloc[0]
    if not isinstance(hts, float):
        hts = hts.get('hashtags')
        for ht in hts:
            hashtags.append(ht.get('text').lower())
    hashtaglist.append(hashtags)

# %%
# Appending these new lists as columns

NintendoTweets['cleanedtext'] = cleanedTweets
NintendoTweets['hashtags'] = hashtaglist

# %%
NintendoTweets
# Out:
#                                                                                                text  \
# 0                                                                       IT BEGINS!! #NintendoDirect
# 1          RT @funkemcfly: lord forgive me but i'm back on my Smash 🅱️ros 🅱️ullshit #NintendoE3 #E3
# 2                    The Nintendo presentation is starting!!! My body is ready. #E32018 #NintendoE3
# 3       RT @CelopanYT: VIENDO EL NINTENDO DIRECT CON VOSOTROS!! #NintendoE3 https://t.co/IsuHMxK9Jt
# 4                                                                         YO HERE WE GO #NintendoE3
# ...                                                                                             ...
# 104690                             RENDEZ NOUS ANIMAL CROSSING SVP JE VAIS FAIRE UN AVC #NintendoE3
# 104691                      RT @ThatRetro: Rated E for Everyone #NintendoE3 https://t.co/RhWe8BTQWQ
# 104692                                           RT @napricott: 犬種を変える謎のこだわり #E32018⁠ ⁠ #NintendoE3
# 104693                                           Already have one, awesome. https://t.co/wCNTohs4pL
# 104694                      RT @Ben__Harlan: #e3 #NintendoE3 \nNever forget https://t.co/HkElG5mOL7
#
#                                                                                                                                                                                                        entities  \
# 0                                                                                               {'hashtags': [{'text': 'NintendoDirect', 'indices': [12, 27]}], 'urls': [], 'user_mentions': [], 'symbols': []}
# 1       {'hashtags': [{'text': 'NintendoE3', 'indices': [73, 84]}, {'text': 'E3', 'indices': [85, 88]}], 'urls': [], 'user_mentions': [{'screen_name': 'funkemcfly', 'name': 'funké3', 'id': 554060069, 'id_...
# 2                                                          {'hashtags': [{'text': 'E32018', 'indices': [59, 66]}, {'text': 'NintendoE3', 'indices': [67, 78]}], 'urls': [], 'user_mentions': [], 'symbols': []}
# 3       {'hashtags': [{'text': 'NintendoE3', 'indices': [56, 67]}], 'urls': [{'url': 'https://t.co/IsuHMxK9Jt', 'expanded_url': 'https://www.twitch.tv/celopan/', 'display_url': 'twitch.tv/celopan/', 'indi...
# 4                                                                                                   {'hashtags': [{'text': 'NintendoE3', 'indices': [14, 25]}], 'urls': [], 'user_mentions': [], 'symbols': []}
# ...                                                                                                                                                                                                         ...
# 104690                                                                                              {'hashtags': [{'text': 'NintendoE3', 'indices': [53, 64]}], 'urls': [], 'user_mentions': [], 'symbols': []}
# 104691  {'hashtags': [{'text': 'NintendoE3', 'indices': [36, 47]}], 'urls': [], 'user_mentions': [{'screen_name': 'ThatRetro', 'name': 'Retro: Pride Month Enthusiast 🏳️‍🌈', 'id': 243866714, 'id_str': '243...
# 104692  {'hashtags': [{'text': 'E32018', 'indices': [28, 35]}, {'text': 'NintendoE3', 'indices': [39, 50]}], 'urls': [], 'user_mentions': [{'screen_name': 'napricott', 'name': '推しが復活しました', 'id': 799769679...
# 104693  {'hashtags': [], 'urls': [{'url': 'https://t.co/wCNTohs4pL', 'expanded_url': 'https://twitter.com/NintendoEurope/status/1006581630608203777', 'display_url': 'twitter.com/NintendoEurope…', 'indices...
# 104694  {'hashtags': [{'text': 'e3', 'indices': [17, 20]}, {'text': 'NintendoE3', 'indices': [21, 32]}], 'urls': [], 'user_mentions': [{'screen_name': 'Ben__Harlan', 'name': 'Ben', 'id': 13666862, 'id_str...
#
#                               cleanedtext              hashtags
# 0                               it begin       [nintendodirect]
# 1             lord forgive back smash ro       [nintendoe3, e3]
# 2       presentation starting body ready   [e32018, nintendoe3]
# 3                          el direct con           [nintendoe3]
# 4                                here go           [nintendoe3]
# ...                                   ...                   ...
# 104690                animal crossing un           [nintendoe3]
# 104691                             rated           [nintendoe3]
# 104692                                     [e32018, nintendoe3]
# 104693               already one awesome                     []
# 104694                      never forget       [e3, nintendoe3]
#
# [104695 rows x 4 columns]

# %%
flat_list = []
hashtagdict = {}
for sublist in hashtaglist:
    for item in sublist:
        flat_list.append(item)
        if item in hashtagdict.keys():
            hashtagdict[item] = hashtagdict[item] + 1
        else:
            hashtagdict[item] = 1

# %% [markdown]
# Here it's time to identify all the hashtags of interest, specifically about the 4 main titles we're interested in.

# %%
uniquehashtags = set(flat_list)

# %%
# Getting most frequently occuring hashtags in sorted order
hashtagdictsorted = {k: v for k, v in sorted(hashtagdict.items(), key=lambda item: item[1], reverse=True)}
hashtagdictsorted
# Out:
# {'nintendoe3': 72681,
#  'e32018': 32178,
#  'nintendodirect': 17136,
#  'e3': 10386,
#  'smashbros': 9559,
#  'nintendoswitch': 8430,
#  'fireemblem': 1853,
#  'supersmashbros': 1730,
#  'supersmashbrosultimate': 1383,
#  'gamespote3': 1346,
#  'smashbrosswitch': 1341,
#  'fortnite': 1212,
#  'e3jvcom': 891,
#  'marioparty': 890,
#  'nintendo': 876,
#  'smashbrosultimate': 749,
#  'eshop': 720,
#  'xenobladechronicles2': 617,
#  'pokeballplus': 485,
#  'splatoon': 431,
#  'pokemonletsgo': 405,
#  'daemonxmachina': 395,
#  'supermarioparty': 363,
#  'nintendoe32018': 330,
#  'octopathtraveler': 311,
#  'hollowknight': 305,
#  'nintendodirectjp': 296,
#  'smashswitch': 289,
#  'overcooked2': 284,
#  'animalcrossing': 266,
#  'pokemon': 251,
#  'nintendodirecte3': 236,
#  'switch': 213,
#  'smash': 210,
#  'ridley': 164,
#  'zelda': 159,
#  'meroe3': 155,
#  'e30218': 151,
#  'fireemblemthreehouses': 135,
#  'merie3': 127,
#  'supersmashbrosswitch': 126,
#  'tech': 125,
#  'innovation': 125,
#  'e3caroju': 115,
#  'ebe3': 99,
#  'killerqueenblack': 99,
#  'e3g1': 92,
#  'gamestope3': 78,
#  'everyoneishere': 75,
#  'pokéballplus': 74,
#  '5thflowerpathwithbts': 70,
#  'e3gk': 70,
#  'スマブラ': 69,
#  'youtubee3': 66,
#  'gameate3': 65,
#  'e32017': 64,
#  'fortnitee3': 63,
#  'splatoon2': 63,
#  'ultimate': 63,
#  'nnesagae3': 61,
#  'rte3': 59,
#  'dragonballfighterz': 59,
#  'niconico': 57,
#  'smashultimate': 53,
#  'hypepore3': 46,
#  'gronkhtv': 46,
#  'e3atgame': 46,
#  'fornite': 46,
#  'saysgamerse3': 45,
#  'metroidprime4': 44,
#  'blacknerde3': 44,
#  'e3beans': 42,
#  'ptce3': 41,
#  'felizmartes': 38,
#  'ninte3ndo': 38,
#  'metroid': 37,
#  'xenoblade': 37,
#  'nintendo3ds': 36,
#  'e3nintendo': 36,
#  'gse32018': 36,
#  'gaming': 36,
#  'playstatione3': 35,
#  'ssb': 33,
#  'sonye3': 32,
#  'xboxe3': 31,
#  'fizzvse3': 30,
#  'e3levelup': 30,
#  'nintendotreehouse': 30,
#  'squareenixe3': 30,
#  '슈퍼마리오파티': 30,
#  'eethreeperbowl2018': 28,
#  'martesconpame': 28,
#  'bomberman': 28,
#  'tmog': 27,
#  'gs_e3': 27,
#  'freewolf': 27,
#  'ニンテンドーダイレクト': 26,
#  'ojeraspore3': 26,
#  'mixere3': 26,
#  'gameready': 25,
#  'gamedailye3': 25,
#  'gamerstyle3': 24,
#  'disneyxd': 24,
#  'e3ign': 24,
#  'ssbu': 24,
#  'mario': 23,
#  'tuesdaythoughts': 23,
#  'n3ate3': 23,
#  'e3coliseum': 23,
#  'nerdcouncile3': 22,
#  'smash5': 22,
#  'gamingclerks': 21,
#  '大乱闘スマッシュブラザーズ': 21,
#  'ssbultimate': 21,
#  'twitch': 20,
#  'kamene3': 20,
#  'e3rbs': 20,
#  'جيمرز': 20,
#  'meme3verso': 19,
#  'trumpkimsummit': 19,
#  'money': 19,
#  'natewatches': 18,
#  'e3eurogamer': 18,
#  'e32108': 18,
#  'letsgopikachu': 18,
#  'cutree3': 18,
#  'gamernation': 18,
#  'supersmashultimate': 18,
#  'lasvegas': 17,
#  'abundancia': 17,
#  'coachramonaguero': 17,
#  'coach': 17,
#  'creeenti': 17,
#  'nlp': 17,
#  'time': 17,
#  'valor': 17,
#  'sinlimites': 17,
#  'usa': 17,
#  'sesion': 17,
#  'lanatasinfiltro': 17,
#  'music': 17,
#  'gamecube': 17,
#  '포트나이트': 17,
#  'selygae3': 16,
#  'elotropodcast': 16,
#  'ニンテンドースイッチ': 16,
#  'twewy': 16,
#  'ddm': 16,
#  'animalcrossingswitch': 15,
#  'ne3': 15,
#  'e2018': 15,
#  'tornathegoldencountry': 15,
#  'diadosnamorados': 15,
#  'overcooked': 15,
#  'yoshi': 15,
#  'rap': 15,
#  'hiphop': 15,
#  'hype': 14,
#  'esfandome3': 14,
#  'microsofte3': 14,
#  'nindies': 14,
#  'supersmash': 14,
#  'playlist': 14,
#  'nintendo2018': 13,
#  'kwanamie3': 13,
#  'watchmojodoese3': 13,
#  'e3pk': 13,
#  'videogames': 13,
#  'xenoblade2': 13,
#  'inkling': 13,
#  'ubie3': 13,
#  'gamingnews': 12,
#  'trabajoinfantil': 12,
#  'daisy': 12,
#  'cna': 12,
#  'mlcoverse3': 11,
#  'e3tdj': 11,
#  'mew': 11,
#  'theworldendswithyou': 11,
#  'supersmasultimate': 11,
#  'amiibo': 11,
#  'buenmartes': 11,
#  'singapore': 11,
#  'buildthatwall': 11,
#  'puree32018': 10,
#  'snake': 10,
#  'bayonetta': 10,
#  'intrusos': 10,
#  'barcade3': 10,
#  'eaplay': 10,
#  'pietstream': 9,
#  'videogamenews': 9,
#  'daemonmachina': 9,
#  'e3xpnl': 9,
#  'pokemonletsgopikachu': 9,
#  'letsgoeevee': 9,
#  'pokemongo': 9,
#  'bethesdae3': 9,
#  'minecraft': 9,
#  'paladins': 9,
#  'e3ontwitch': 9,
#  'infinitywar': 9,
#  'feminism': 9,
#  'cloudstrife': 9,
#  'ff7': 9,
#  'patobox': 9,
#  'indiegame': 9,
#  'live': 8,
#  'latism': 8,
#  'pokémon': 8,
#  'daihyo': 8,
#  'アルピーdcg': 8,
#  '小原鞠莉生誕祭2018': 8,
#  'マツコの知らない世界': 8,
#  'pikachu': 8,
#  'fortniteswitch': 8,
#  'starlink': 8,
#  'dbfz': 8,
#  'bayonetta3': 8,
#  'fifa19': 8,
#  'followme': 8,
#  'mother3': 8,
#  'ffvii': 8,
#  'smashbrose3': 8,
#  'demonxmachina': 7,
#  'zidanesg1e318': 7,
#  'supermario': 7,
#  'e3akb': 7,
#  'e3svetxav': 7,
#  'gamerse3': 7,
#  'hollownight': 7,
#  'captaintoad': 7,
#  'link': 7,
#  'nintendowone3': 7,
#  'megaman': 7,
#  'wolf': 7,
#  'waluigi': 7,
#  'levelupongaming': 7,
#  'smashbrosdirect': 7,
#  'noaltrabajoinfantil': 7,
#  'smashdirect': 7,
#  'ripbayonetta3': 7,
#  'cerca': 6,
#  'mirioneta': 6,
#  'gamers': 6,
#  'starfox': 6,
#  'teamaddv': 6,
#  'e3theenemy': 6,
#  'squareenix': 6,
#  'xbox': 6,
#  'nswitch': 6,
#  'modelocafé': 6,
#  'breathofthewild': 6,
#  'fortine': 6,
#  'sma5h': 6,
#  'sbu': 6,
#  'waluigiforsmash': 6,
#  'metalgearsolid': 6,
#  'samus': 6,
#  'squidsisters': 6,
#  'smashe3': 6,
#  'repost': 6,
#  'e3max': 5,
#  'deamonxmachina': 5,
#  'nostalgia': 5,
#  'dlc': 5,
#  'pokemonletsgoeevee': 5,
#  'fzero': 5,
#  'fortnight': 5,
#  'stardewvalley': 5,
#  'nintendoeshop': 5,
#  'octopathtraveller': 5,
#  'fighterz': 5,
#  'darksouls': 5,
#  'falloutshelter': 5,
#  'megaman11': 5,
#  'ニンダイ': 5,
#  'suoersmashbrosultimate': 5,
#  'supersmashbrothersultimate': 5,
#  'nintendowins': 5,
#  'pikmin': 5,
#  'pcgamingshow': 5,
#  'liveblog': 5,
#  'livechat': 5,
#  'soyboy': 4,
#  'graphicdesigner': 4,
#  'graphic': 4,
#  'designer': 4,
#  'logo': 4,
#  'brochures': 4,
#  'flyer': 4,
#  'poster': 4,
#  'postcard': 4,
#  'banner': 4,
#  'e3_2018': 4,
#  'कबीरपरमात्मा_के_चमत्कार': 4,
#  'doodle': 4,
#  'quickdoodle': 4,
#  'pressconference': 4,
#  '任天堂': 4,
#  'ps4': 4,
#  'torna': 4,
#  'reggie': 4,
#  'armoredcore': 4,
#  'pokémonletsgo': 4,
#  'letsgo': 4,
#  'mariopartyswitch': 4,
#  'cne32018': 4,
#  'news': 4,
#  'wgge3': 4,
#  'eaplay2018': 4,
#  'battleroyale': 4,
#  'fb': 4,
#  'nintenodirect': 4,
#  'team17': 4,
#  'hallowknight': 4,
#  'youtube': 4,
#  'enlavidanodebes': 4,
#  'ninjala': 4,
#  'esports': 4,
#  'rahulexposesrss': 4,
#  'iceclimbers': 4,
#  'pacman': 4,
#  'melee': 4,
#  'smashbrothers': 4,
#  'supersamshbrosultimate': 4,
#  'pokemontrainer': 4,
#  'solidsnake': 4,
#  'capitalsparade': 4,
#  'echofighters': 4,
#  'pubg': 4,
#  'ignnae3': 4,
#  'spyroreignitedtrilogy': 4,
#  'supersmashbrosdirect': 4,
#  'supermashbrosultimate': 4,
#  'sony': 4,
#  'ubisofte3': 4,
#  'twitchtv': 3,
#  'e3coolfamily': 3,
#  'ign': 3,
#  'videojuegos': 3,
#  'rpg': 3,
#  'e3expo': 3,
#  'xenobladechronicals2': 3,
#  'nintendoswitche3': 3,
#  'e32019': 3,
#  'euwithdrawalbill': 3,
#  'jeuxvideo': 3,
#  'ポケモン': 3,
#  '12jun': 3,
#  'martesdetetas': 3,
#  'pulse': 3,
#  'fireemblemswitch': 3,
#  'new': 3,
#  'fe16': 3,
#  'bitcoin': 3,
#  'フォートナイト': 3,
#  'tocg': 3,
#  'theothercoast': 3,
#  'e3nocafé': 3,
#  'arenaofvalor': 3,
#  'cosp11': 3,
#  'please': 3,
#  'trumpkim': 3,
#  'darksoulsremastered': 3,
#  'crashbandicoot': 3,
#  'wasteland2': 3,
#  'dragonball': 3,
#  'ark': 3,
#  'sakurai': 3,
#  'octoexpansion': 3,
#  'e318': 3,
#  'smash4': 3,
#  'cloud': 3,
#  'apêxonados': 3,
#  'toonlink': 3,
#  'adrenalive': 3,
#  'roster': 3,
#  'cappy': 3,
#  'supermarioodyssey': 3,
#  'ryu': 3,
#  'ptdiscord': 3,
#  'adioscanayin': 3,
#  'adiosanaya': 3,
#  'gamersunite': 3,
#  'premioalamor': 3,
#  'inklings': 3,
#  'nintendolabo': 3,
#  'irohero': 3,
#  '5thflowerpathwithbts5thflo': 3,
#  'neverbegameover': 3,
#  'wtf': 3,
#  'سوپراسمش\u200cبراس': 3,
#  'microsoft': 3,
#  'hiimdaisy': 3,
#  'eletronica3': 3,
#  'maxoee3': 3,
#  'ea': 3,
#  'gamecubecontroller': 3,
#  'stone': 3,
#  'amiibos': 3,
#  'e132018': 3,
#  'mxnrxn': 3,
#  '大乱闘スマッシュブラザーズspecial': 3,
#  'nintendoe3bingo2018': 3,
#  'kevincostner': 3,
#  'warriorsparade': 3,
#  'be3': 3,
#  'thankyoutrump': 3,
#  'canalgotye3': 3,
#  'xenomorph': 3,
#  'inifnitywar': 3,
#  'fifa18': 3,
#  'h1z1': 3,
#  'fussball': 3,
#  'fut18': 3,
#  'wm2018': 3,
#  'cebit18': 3,
#  'panini': 3,
#  'diemannschaft': 3,
#  'love': 3,
#  'watching': 2,
#  'legendofzelda': 2,
#  'masternever': 2,
#  'givemeanimalcrossing': 2,
#  'gundam': 2,
#  'earthbound': 2,
#  'nw': 2,
#  'badboa': 2,
#  'xenobladechronicles': 2,
#  'metalwolfchaosxd': 2,
#  'daemon': 2,
#  'thelastofuspart2': 2,
#  'deathstranding': 2,
#  'xboxone': 2,
#  'thelastofuspartii': 2,
#  'streamer': 2,
#  'pokemonletsgopickachu': 2,
#  'pokemonletsgoevoli': 2,
#  'letsgopokemon': 2,
#  'events': 2,
#  'marketing': 2,
#  'eth': 2,
#  'pokemonlets': 2,
#  'socialcheap': 2,
#  'empathyda': 2,
#  'charitytuesday': 2,
#  'hypetrain': 2,
#  'pokemonsletsgopikachu': 2,
#  'omg': 2,
#  'feelsbadman': 2,
#  'maga': 2,
#  'anime': 2,
#  'tokyomiragesessions': 2,
#  'supersmashbrothersswitch': 2,
#  'supermariopartyswitch': 2,
#  'veshnews': 2,
#  'veshgaming': 2,
#  'nerdarmy': 2,
#  'fortninte': 2,
#  'fireemblemthreehouse': 2,
#  'gratis': 2,
#  'sora4smash': 2,
#  'elmomentohallegado': 2,
#  'fortnitegratis': 2,
#  'crossplay': 2,
#  'nintedoswitch': 2,
#  'nintendogames': 2,
#  'instagaming': 2,
#  'indiegames': 2,
#  'indiegamedev': 2,
#  'killerqueen': 2,
#  'roguelike': 2,
#  'indie': 2,
#  'ogxpartychat': 2,
#  'donkeykong': 2,
#  'fntech': 2,
#  'sushistriker': 2,
#  'mariorabbids': 2,
#  'justdance2019': 2,
#  'starlinkgame': 2,
#  'justdance': 2,
#  'kickstarter': 2,
#  'darksoulds': 2,
#  'pixark': 2,
#  'wewantanimalcrossing': 2,
#  'mariotennis': 2,
#  'wolfensteinii': 2,
#  'e3entoma5': 2,
#  'chavitos': 2,
#  'sense8finale': 2,
#  'paris': 2,
#  'fifa': 2,
#  'supersmashbrothers': 2,
#  'jackryan': 2,
#  'golisoda2': 2,
#  'lit': 2,
#  'botw': 2,
#  'smashforeveryone': 2,
#  'nintendiodirecto': 2,
#  'smashbrossultimate': 2,
#  'dies': 2,
#  'nogamer': 2,
#  'gamersegames': 2,
#  'smashinfinite': 2,
#  'raw': 2,
#  'sdlive': 2,
#  'falconpunch': 2,
#  'lopetegui': 2,
#  'smashtiep': 2,
#  'supsnakewelcomeback': 2,
#  'griezmann': 2,
#  'adrenaline': 2,
#  'snakeisback': 2,
#  'hollowkinight': 2,
#  'n64mini': 2,
#  'minifigure': 2,
#  'samshbros': 2,
#  'markets': 2,
#  'entrepreneur': 2,
#  'e3201': 2,
#  'kirby': 2,
#  'mgs': 2,
#  'e3gameblog': 2,
#  'ماریوپارتی': 2,
#  'dantesquad': 2,
#  'cnx18': 2,
#  'peach': 2,
#  'caroju': 2,
#  'rbtv': 2,
#  'e3thenemy': 2,
#  'princessdaisy': 2,
#  'スプラトゥーン2': 2,
#  'metroidprime': 2,
#  'nintendoalwayswins': 2,
#  'thelegendofzelda': 2,
#  'majorasmask': 2,
#  'imalimuni': 2,
#  'sibanyestillwater': 2,
#  'singaporesummit': 2,
#  'ridleyforsmash': 2,
#  'noanimalcrossing': 2,
#  'ridleyinsmash': 2,
#  'supersmashbrosultimatee3': 2,
#  'supersmashdirect': 2,
#  'fifa2019': 2,
#  'luigismansion': 2,
#  'direct': 2,
#  'supersmashbrosulimate': 2,
#  'nintendowon': 2,
#  'gaymer': 2,
#  'dead': 2,
#  'slbpooptweet': 2,
#  'worldcup': 2,
#  '2018btsfesta': 2,
#  'itwasallsmashbros': 2,
#  'mobile': 2,
#  'eae3': 2,
#  'nachrichten': 2,
#  'ripmario': 2,
#  'fatahkafatwa': 2,
#  'e3revuejv': 2,
#  'spyro': 2,
#  'mother': 2,
#  'charity': 2,
#  'donate': 2,
#  'onthisday': 2,
#  'スマブラsp': 2,
#  'abao': 2,
#  'bccrss': 1,
#  'babylon': 1,
#  'idslyingthere': 1,
#  'idsillegal': 1,
#  '2k18': 1,
#  'nintendoiscoming': 1,
#  'crash4smash': 1,
#  'nintendodirectr': 1,
#  'showtime': 1,
#  'gametubede': 1,
#  '6hourstogo': 1,
#  'canlı': 1,
#  'nintendotürkiye': 1,
#  'nintendotr': 1,
#  'e3shitposting': 1,
#  'notlatetotheparty': 1,
#  'ni': 1,
#  'beer': 1,
#  'wiiu': 1,
#  'eventos': 1,
#  'e3expo2018': 1,
#  'mech': 1,
#  'virtual': 1,
#  'mechnintendogreatagain': 1,
#  'gamer': 1,
#  'nerd': 1,
#  'stdrenegade': 1,
#  'robotech': 1,
#  'awful': 1,
#  'robots': 1,
#  'gross': 1,
#  'shenmue3': 1,
#  'residentevil2': 1,
#  'fistofthenorthstar': 1,
#  'rt': 1,
#  'rayman4smash': 1,
#  'demonmachinima': 1,
#  'facebookgaming': 1,
#  'wordpress': 1,
#  'web': 1,
#  'developer': 1,
#  'webdeveloper': 1,
#  'نینتندو': 1,
#  'e3news': 1,
#  'gamerverein': 1,
#  'gvr': 1,
#  'chisteslex': 1,
#  'perdón': 1,
#  'xenogears': 1,
#  'diamondageofarchitecture': 1,
#  'ilookup': 1,
#  'la': 1,
#  'machina': 1,
#  'dimondxmachine': 1,
#  'daimonxmachina': 1,
#  'jrpg': 1,
#  'nvidiageforce': 1,
#  'dxp': 1,
#  'memes': 1,
#  'simpson': 1,
#  'gears5': 1,
#  'callofdutyblackops4': 1,
#  'nigdyniezagrambozadużojrpgów': 1,
#  'videogamescomefromjapan': 1,
#  'daemonxmachine': 1,
#  'xenovlade': 1,
#  'marvelous': 1,
#  'daemosxmachina': 1,
#  'xenobladecronicles': 1,
#  'deadarticgames': 1,
#  'nintendoesp': 1,
#  'fuckinmechs': 1,
#  'reggieforsmash5': 1,
#  'streaming': 1,
#  'thebigman': 1,
#  'supportsmallstreams': 1,
#  'teameevee': 1,
#  'xc2': 1,
#  'battutetristi': 1,
#  'deamonxmacina': 1,
#  'notmypokemon': 1,
#  'evo2018': 1,
#  'razer': 1,
#  'xenobladex': 1,
#  'xenobladeschronicles': 1,
#  'calledit': 1,
#  'gke3': 1,
#  'leak': 1,
#  'ゼノブレイド２': 1,
#  'youtuberscatalans': 1,
#  'barcelona': 1,
#  'xenoversechronicles2': 1,
#  'demonxmechina': 1,
#  'tellmemore': 1,
#  'reggi': 1,
#  'doingitright': 1,
#  'blockchain': 1,
#  'dappdotcomlaunch': 1,
#  'igne3': 1,
#  'impatient': 1,
#  'reggisreads': 1,
#  'bingocardping': 1,
#  'be32018': 1,
#  'gottacatchemall': 1,
#  'nintedodirect': 1,
#  'pokeman': 1,
#  'letsgopickachu': 1,
#  'fingerscrossed': 1,
#  'world': 1,
#  'coin': 1,
#  'joycon': 1,
#  'marioparty11': 1,
#  'allcaps': 1,
#  'stanleycup': 1,
#  'opieop': 1,
#  'starsnotcars': 1,
#  'teamchaose3': 1,
#  'mariopary': 1,
#  'hyped': 1,
#  'xenobladeschronicles2': 1,
#  'ピカブイ': 1,
#  'babysteps': 1,
#  'wah': 1,
#  'warioware': 1,
#  'fireemblemthreeheroes': 1,
#  'onlyonswitch': 1,
#  'fireemblem3houses': 1,
#  'cryptocurrency': 1,
#  'fieremblemthreehouses': 1,
#  'nintendoe3bingo': 1,
#  'trending': 1,
#  'clutch23': 1,
#  'bummer': 1,
#  'fireemblemthrehouse': 1,
#  'pokemoneve': 1,
#  'pokemonpikachu': 1,
#  'caseritas': 1,
#  'flameemblem': 1,
#  'fireemblemthreestories': 1,
#  'pokemonsnap': 1,
#  'fireeemblem': 1,
#  'fireenblem': 1,
#  'letsgoevoli': 1,
#  'trailer': 1,
#  'fireemblemtreehouses': 1,
#  'fireemblamthreehouses': 1,
#  '45quidformew': 1,
#  'yawn': 1,
#  'fortniteee': 1,
#  'myheroacademia': 1,
#  'chancewasright': 1,
#  'fortniteforswitch': 1,
#  'shadowdrop': 1,
#  'overratedgame': 1,
#  'vinagre3': 1,
#  'vapelife': 1,
#  'primaveralandia': 1,
#  'pogchamp': 1,
#  'googleit': 1,
#  'e32why': 1,
#  'ffxv': 1,
#  'london': 1,
#  'nindie': 1,
#  'meetmeatthebattlefield': 1,
#  'lovense': 1,
#  'windows': 1,
#  'e3btg': 1,
#  'karten': 1,
#  'deutschland': 1,
#  'whycantiplayasshaqyet': 1,
#  'ignisscientia': 1,
#  'animalcrossings': 1,
#  'chopchopchopchopchop': 1,
#  'i': 1,
#  'cooking': 1,
#  'cookingmama': 1,
#  'ericwasright': 1,
#  'cheaperwhenyoutradeatgame': 1,
#  'fortenite': 1,
#  'newgames': 1,
#  'respect': 1,
#  'gimmegames': 1,
#  'guaranteedtoblowyourmind': 1,
#  'holloknight': 1,
#  'overcook2': 1,
#  'troll': 1,
#  'گیم': 1,
#  'killerqueenbee': 1,
#  'octopathtravaler': 1,
#  'dkreanimate': 1,
#  'threehouses': 1,
#  'trendingeam': 1,
#  'exclusive': 1,
#  'mechaphilie': 1,
#  'fortnitebattleroyale': 1,
#  'türkiyeninumudufizikçi': 1,
#  'agchatoz': 1,
#  'dbz': 1,
#  'pamforbay3': 1,
#  'yougamerse3': 1,
#  'nsanetrilogy': 1,
#  'twitchnetworks': 1,
#  'toomanygoodgames': 1,
#  'jumpandrun': 1,
#  'livestreaming': 1,
#  'when': 1,
#  'dragonballfigtherz': 1,
#  'montreal': 1,
#  'wasteland': 1,
#  'theworldendswithyoufinalremix': 1,
#  'dragonballfighters': 1,
#  'dbzfz': 1,
#  'wolfenstein': 1,
#  'dailyhottake': 1,
#  'theworldenwithyou': 1,
#  'eyeroll': 1,
#  'dragonballfightersz': 1,
#  'octopathtimetraveller': 1,
#  'fortnitenintendo': 1,
#  'snkheroines': 1,
#  'smashbro': 1,
#  'teen': 1,
#  'pvt': 1,
#  'c2c': 1,
#  'monsterhuntergenerations': 1,
#  'monsterhunterworld': 1,
#  'فایرامبلم': 1,
#  'smashv': 1,
#  'kirbyforever': 1,
#  'number6': 1,
#  'newguardian': 1,
#  'sarcasm': 1,
#  'wolfenstein2': 1,
#  'bowser': 1,
#  'dayanidhimaran': 1,
#  'maxis': 1,
#  'estres': 1,
#  'windwaker': 1,
#  'raymaninsmash2018': 1,
#  'e32018s': 1,
#  'soylaunicaalaquenolegustaestejuego': 1,
#  'ssm': 1,
#  'mustcosplay': 1,
#  'worldrugbyu20s': 1,
#  'adultchild': 1,
#  'smasbros': 1,
#  'nintendoswitc': 1,
#  'carcassonne': 1,
#  'ff7remake': 1,
#  'snaaaaaaake': 1,
#  'nintendoomed': 1,
#  'sfgiants': 1,
#  'e3v': 1,
#  'fact': 1,
#  'imsoexcited': 1,
#  'killerqueen4lyfe': 1,
#  'supermsashbros': 1,
#  'fittingtitle': 1,
#  'yearofluigi': 1,
#  'overcoocked2': 1,
#  'corin': 1,
#  'bowserjr': 1,
#  'miifighters': 1,
#  'pokémontrainer': 1,
#  'newrelease': 1,
#  'sakuraiisatroll': 1,
#  'nintendoinvitational': 1,
#  'dbfighterz': 1,
#  'crashnsanetrilogy': 1,
#  'cantpleaseeveryone': 1,
#  'nayan63': 1,
#  'lakshmi': 1,
#  'jungaaudiofromtomorrow': 1,
#  'nowaluigi': 1,
#  'houston': 1,
#  'comingsoon': 1,
#  'tictoc': 1,
#  'nintendodirectスマブラ全員出すのか': 1,
#  'crossover': 1,
#  'smashbrotheresultimate': 1,
#  'smbultimate': 1,
#  'supersmashbrosultumate': 1,
#  'tecnología': 1,
#  'smashbroswii': 1,
#  'supersmashbrosbrowl': 1,
#  'supersmashbross': 1,
#  'playstationallstarsbattleroyale': 1,
#  'supersmashbrosunlimited': 1,
#  'supermariodash': 1,
#  'marios': 1,
#  'links': 1,
#  'masterchief': 1,
#  'yes': 1,
#  'persona5': 1,
#  'ooc': 1,
#  'theworldsendswithyou': 1,
#  'preordered': 1,
#  'evenfemalepikachuishere': 1,
#  'pikachulibreisagirl': 1,
#  'main': 1,
#  'fortniteproam': 1,
#  'wrestlingmemes': 1,
#  'everyfighterinhistory': 1,
#  'narendramodi': 1,
#  'salmankhan': 1,
#  'thefinalcountdown': 1,
#  'lostintranslation': 1,
#  'yourteamyourrules': 1,
#  'luchadora': 1,
#  'fake_love_rocking_vibe_mix': 1,
#  'sonicthehedgehog': 1,
#  'wismichu': 1,
#  'lucario': 1,
#  'greninja': 1,
#  'palutena': 1,
#  'themoreyouknow': 1,
#  'meusnaketavivo': 1,
#  'déprime': 1,
#  'squirtlesquad': 1,
#  'e3マスクドデデデ': 1,
#  'avengersinfinitywar': 1,
#  'ssupersmashbros': 1,
#  'smashbbros': 1,
#  'thanksnintendo': 1,
#  'sanic': 1,
#  'valencia': 1,
#  'geno': 1,
#  'supermariorpg': 1,
#  'waveformgaming': 1,
#  'ghoulsquad': 1,
#  'supersmashbrosmelee': 1,
#  '3dprint': 1,
#  'supersmasbroshultimate': 1,
#  'marthallday': 1,
#  'theonlythingworthlivingfor': 1,
#  'reddeadredemption2': 1,
#  'finafantasy': 1,
#  'nintendo3d': 1,
#  'supersmashbro': 1,
#  'tourdesuisse': 1,
#  'smashdirekt': 1,
#  'villagerssowhite': 1,
#  'macron': 1,
#  'experiorproject': 1,
#  'balancelesnoms': 1,
#  'supersmahsbrosultimate': 1,
#  'jurassicworldevolution': 1,
#  'angacom2018': 1,
#  'teamparanoico': 1,
#  'supersmashbrosu': 1,
#  'nintendohype': 1,
#  'excited': 1,
#  'beatemups': 1,
#  'myfavouriteganon': 1,
#  'business': 1,
#  'supersmashbrosultimatedirect': 1,
#  'shadowmoses': 1,
#  'wintendo': 1,
#  'kirbytocapelotas': 1,
#  'wii': 1,
#  'ps3': 1,
#  'ps2': 1,
#  'giantbomb': 1,
#  'amaazing': 1,
#  'cantwait': 1,
#  'bjp': 1,
#  'nintendoe13': 1,
#  'wario': 1,
#  'askingtherealquestions': 1,
#  'itneverends': 1,
#  'dte3': 1,
#  'e3lambda': 1,
#  'nierautomata': 1,
#  'data': 1,
#  'entry': 1,
#  'jumpforce': 1,
#  'wiifittrainer': 1,
#  'jeanmicheljemeuble': 1,
#  'teamkirby': 1,
#  'skywardswordhd': 1,
#  'shantae': 1,
#  'fallout': 1,
#  'regresantodos': 1,
#  'envivo': 1,
#  'giveusmetroid4reggie': 1,
#  'lucinamain': 1,
#  'epic': 1,
#  'idontcareforsmash': 1,
#  'daisydaisydaisydaisydaisydaisy': 1,
#  'nintendoe3aisy': 1,
#  'estupendismo': 1,
#  'smashbrothersultimate': 1,
#  'facepalm': 1,
#  'fucksake': 1,
#  'pubgmobile': 1,
#  'pubgxbox': 1,
#  'pcgaming': 1,
#  'n64': 1,
#  'facts': 1,
#  'playstation': 1,
#  'video': 1,
#  'british': 1,
#  'islam': 1,
#  'makkah': 1,
#  'uk': 1,
#  'sciencetoo': 1,
#  'electionday': 1,
#  'finalfantasyviiremake': 1,
#  'crossingmyfingers': 1,
#  'ready': 1,
#  'getinked': 1,
#  'sephiroth': 1,
#  'smashbrosinfinite': 1,
#  'mariokart': 1,
#  'supersmashbroultimate': 1,
#  'lovingday': 1,
#  'justiceforwaluigi': 1,
#  'working': 1,
#  'rosalina': 1,
#  'lt': 1,
#  'switcheshop': 1,
#  'parentingwins': 1,
#  'supersmashbrosinfinite': 1,
#  'waaaaah': 1,
#  'assistcharacters': 1,
#  'smashbr': 1,
#  'blonde': 1,
#  'milf': 1,
#  'mature': 1,
#  'berlin': 1,
#  'killyourself': 1,
#  ...}

# %% [markdown]
# We can see that 'smashbros', 'fireemblem', and 'marioparty' take up the majority of our hashtags regarding the 3 main titles of interest. Taking Smash Bros for instance though, we can see that there are other hashtags such as 'supersmashbros', 'supersmashbrosultimate', 'smashbrosswitch', 'smashbrosultimate', and many others that are also referencing the same game. Our job here is to unite all the related hashtags under the same one. For Smash Bros, we'll find every alternative hashtag and simply replace them all with 'smashbros'. We'll be finding alternative hashtags by checking for specific keywords. Let's keep a record of how many of each main hashtag we have before this search:
#
#
# smashbros: 9559
#
# fireemblem: 1853
#
# marioparty: 890

# %%
# main hashtags, keywords, list to store related hashtags to corresponding game
majorgames = ['smashbros', 'fireemblem', 'marioparty']

keywords = [['smash', 'bros', 'ultimate', 'ssb'],
            ['fire', 'emblem'],
            ['party']]

majorgamestags = [[], [], []]

# %% [markdown]
# Here, we are storing every related hashtag that is found for each major title, using keywords.

# %%
for i in range(3):
    for keyword in keywords[i]:
        for hashtag in uniquehashtags:
            if keyword in hashtag:
                majorgamestags[i].append(hashtag)

# %% [markdown]
# Now it is time to go into our main data set and replace every alternative hashtag with the main one. Because we cannot directly alter the 'hashtags' column, we'll be instead creating a new column to add on.

# %%
standardizedhashtags = []

for hashtags in hashtaglist:
    newhashtags = []
    for hashtag in hashtags:
        for j in range(3):
            if hashtag in majorgamestags[j]:
                newhashtags.append(majorgames[j])
    standardizedhashtags.append(newhashtags)

# %% [markdown]
# Let's see how many more tweets we have to look at now, per game:

# %%
print("Super Smash Bros. Ultimate: ", standardizedhashtags.count(['smashbros']))
print("Fire Emblem: Three Houses: ", standardizedhashtags.count(['fireemblem']))
print("Super Mario Party: ", standardizedhashtags.count(['marioparty']))
# Out:
# Super Smash Bros. Ultimate:  14952
# Fire Emblem: Three Houses:  1967
# Super Mario Party:  1199

# %% [markdown]
# It's certainly clear that the new Smash Bros. title is by far the most talked about. We were able to get about 5000 more Smash Bros tweets to look at through our hashtag standardization, with a bit more for the other titles as well. Let's make these standardized hashtags a new column.

# %%
NintendoTweets['standardized'] = standardizedhashtags

# %% [markdown]
# We don't care about any tweets that ended up having an empty text body after cleaning, or have irrelevant hashtags. Here we're identifying the indices of such rows of data in order to drop them. We're also cleaning out as many foreign tweets as possible by using a collection of foreign articles.

# %%
rowstodrop = []
foreignarticles = ['el ', 'la ', 'est ', 'de ', 'un ', 'das ', 'sind ', 'en ', 'ba ', 'le ', 'il ', 'al ',
                   'da ', 'su ', 'sur ', 'les ', 'es ', 'der ', 'uns ', 'gut ', 'ob ', 'nos ', 'vas ',
                   'au ', 'des ', 'se ', 'beau ', 'zu ']

for i in range(len(NintendoTweets)):
    if len(cleanedTweets[i]) != 0 and len(standardizedhashtags[i]) != 0:
        for word in foreignarticles:
            if (" " + word) in cleanedTweets[i] or word == cleanedTweets[i]:
                rowstodrop.append(i)
    else:
        rowstodrop.append(i)

# %%
foreignarticles = ['el ', 'la ', 'est ', 'de ', 'un ', 'das ', 'sind ', 'en ', 'ba ', 'le ', 'il ', 'al ',
                   'da ', 'su ', 'sur ', 'les ', 'es ', 'der ', 'uns ', 'gut ', 'ob ', 'nos ', 'vas ',
                   'au ', 'des ', 'se ', 'beau ', 'zu ']

# %%
len(rowstodrop)
# Out:
# 92998

# %%
NintendoTweets = NintendoTweets.drop(rowstodrop)

# %%
# We only care about these two cleaned features of the data set

NintendoTweets = NintendoTweets[['cleanedtext', 'standardized']]

# %%
NintendoTweets
# Out:
#                                                                         cleanedtext  \
# 212                                                             lady smash fighter
# 237                                                      it ha begun direct switch
# 251                                                                        here go
# 266                                                                    live stream
# 703                                                                   it happening
# ...                                                                             ...
# 104644                  every fighter series history joining battle super ultimate
# 104668                             too bad cut away right took ridley wrecked shop
# 104671                  every fighter series history joining battle super ultimate
# 104678  super roster revealed featuring snake every fighter history joining battle
# 104679                                                              super ultimate
#
#        standardized
# 212     [smashbros]
# 237     [smashbros]
# 251     [smashbros]
# 266     [smashbros]
# 703     [smashbros]
# ...             ...
# 104644  [smashbros]
# 104668  [smashbros]
# 104671  [smashbros]
# 104678  [smashbros]
# 104679  [smashbros]
#
# [14952 rows x 2 columns]

# %% [markdown]
# All that's left is to separate the tweet data by game and export them.

# %%
smashindices = []
fireindices = []
partyindices = []

for index in NintendoTweets.index:
    if 'smashbros' in standardizedhashtags[index]:
        smashindices.append(index)
    if 'fireemblem' in standardizedhashtags[index]:
        fireindices.append(index)
    if 'marioparty' in standardizedhashtags[index]:
        partyindices.append(index)

# %%
smashdata = NintendoTweets.loc[smashindices]
firedata = NintendoTweets.loc[fireindices]
partydata = NintendoTweets.loc[partyindices]

# %% [markdown]
# Retweets also count as separate tweets in the data, which begs the question if we should keep them in our data set. Should we only consider unique tweets, or should we also consider the retweets since they add to the quantative representation of sentiments? I believe that they should be included, because I don't think people need to necessarily post an original tweet to reflect positive sentiment. If for example there were 100 positive tweets that were in reality only 1 original tweet and 99 retweets, I believe that they should be treated as 100 positive tweets. If we were to ignore duplicates, then that would be removing 99 positive tweets, regardless of uniqueness.
#
# We'll leave the data sets as are, and export them.

# %%
smashdata.to_csv('smashdata.csv')
firedata.to_csv('firedata.csv')
partydata.to_csv('partydata.csv')
